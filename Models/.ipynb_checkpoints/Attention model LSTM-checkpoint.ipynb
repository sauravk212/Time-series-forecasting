# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import math
from keras.layers import LSTM, RepeatVector, TimeDistributed, Bidirectional

# %%
dataframe = pd.read_csv('output2.csv',usecols=[1]).clip(lower=0).astype('float32')
dataframe = dataframe.iloc[:12000,:]

# %%
plt.plot(dataframe)

# %%
scaler = MinMaxScaler(feature_range=(0, 1)) #Also try QuantileTransformer
dataset = scaler.fit_transform(dataframe)

# %%
dataset.shape
# Out:
# (12000, 1)

# %%
train_size = int(len(dataset) * 0.80)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
test.shape
# Out:
# (2400, 1)

# %%
train.shape
# Out:
# (9600, 1)

# %%
def to_sequences(dataset, time_window,output):
    x = []
    y = []

    for i in range(len(dataset)-time_window-1-output):
        #print(i)
        window = dataset[i:(i+time_window), 0]
        x.append(window)
        y.append(dataset[i+time_window:i+time_window+output, 0])

    return  np.array(x), np.array(y)

# %%
time_window = 10
output=20 # Number of time steps to look back
#Larger sequences (look further back) may improve forecasting.

trainX, trainY = to_sequences(train, time_window, output)
testX, testY = to_sequences(test, time_window,output)

# %%
trainY.shape
# Out:
# (9569, 20)

# %%
trainX = trainX.reshape(trainX.shape[0],trainX.shape[1],1)
testX = testX.reshape(testX.shape[0],testX.shape[1],1)

# %%
import keras
from keras import layers
import tensorflow as tf

# %%
def lstm_attention_model(input_shape):
    inputs = keras.Input(shape=input_shape)

    # LSTM layer
    lstm = Bidirectional(LSTM(50, activation="elu",return_sequences=True))(inputs)

    # Attention mechanism
    attention = layers.Dense(1, activation='elu')(lstm)
    attention = layers.Flatten()(attention)
    attention = layers.Activation('softmax')(attention)
    attention = layers.RepeatVector(100)(attention)
    attention = layers.Permute([2, 1])(attention)
    attention = layers.Multiply()([lstm, attention])
    attention = layers.Lambda(lambda x: tf.reduce_sum(x, axis=1))(attention)

    # Output layer
    outputs = layers.Dense( output )(attention)
    # outputs = layers.LeakyReLU(0.2)(outputs)
    # Compile the model
    model = keras.Model(inputs=inputs, outputs=outputs)
    model.compile(loss='mse', optimizer='adam')

    return model

# %%
model2=lstm_attention_model(input_shape=(10,1))
# Out:
# WARNING:tensorflow:From C:\Users\techno\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\core.py:184: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.

# %%
model2.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)      │ (None, 10, 1)             │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ bidirectional (Bidirectional) │ (None, 10, 100)           │          20,800 │ input_layer[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 10, 1)             │             101 │ bidirectional[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ flatten (Flatten)             │ (None, 10)                │               0 │ dense[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation (Activation)       │ (None, 10)                │               0 │ flatten[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ repeat_vector (RepeatVector)  │ (None, 100, 10)           │               0 │ activation[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ permute (Permute)             │ (None, 10, 100)           │               0 │ repeat_vector[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multiply (Multiply)           │ (None, 10, 100)           │               0 │ bidirectional[0][0],       │
# │                               │                           │                 │ permute[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lambda (Lambda)               │ (None, 100)               │               0 │ multiply[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_1 (Dense)               │ (None, 20)                │           2,020 │ lambda[0][0]               │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 22,921 (89.54 KB)
#  Trainable params: 22,921 (89.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model2.fit(trainX, trainY, batch_size=32 , validation_data=(testX, testY),epochs=100)
# Out:
# Epoch 1/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 14s 17ms/step - loss: 0.0534 - val_loss: 0.0133
# Epoch 2/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0135 - val_loss: 0.0125
# Epoch 3/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - loss: 0.0123 - val_loss: 0.0115
# Epoch 4/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0113 - val_loss: 0.0112
# Epoch 5/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0098 - val_loss: 0.0112
# Epoch 6/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0098 - val_loss: 0.0089
# Epoch 7/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - loss: 0.0097 - val_loss: 0.0122
# Epoch 8/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 9/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0096 - val_loss: 0.0088
# Epoch 10/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0098 - val_loss: 0.0103
# Epoch 11/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0102 - val_loss: 0.0089
# Epoch 12/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0096 - val_loss: 0.0092
# Epoch 13/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0094 - val_loss: 0.0087
# Epoch 14/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0096 - val_loss: 0.0088
# Epoch 15/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0098 - val_loss: 0.0085
# Epoch 16/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0091 - val_loss: 0.0087
# Epoch 17/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0092 - val_loss: 0.0084
# Epoch 18/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0097 - val_loss: 0.0094
# Epoch 19/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0091 - val_loss: 0.0084
# Epoch 20/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0092 - val_loss: 0.0102
# Epoch 21/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.0094 - val_loss: 0.0085
# Epoch 22/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0089 - val_loss: 0.0082
# Epoch 23/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0090 - val_loss: 0.0094
# Epoch 24/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0085 - val_loss: 0.0080
# Epoch 25/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0090 - val_loss: 0.0088
# Epoch 26/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0092 - val_loss: 0.0104
# Epoch 27/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0110 - val_loss: 0.0093
# Epoch 28/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.0085 - val_loss: 0.0087
# Epoch 29/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0082 - val_loss: 0.0083
# Epoch 30/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.0086 - val_loss: 0.0096
# Epoch 31/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.0090 - val_loss: 0.0082
# Epoch 32/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.0091 - val_loss: 0.0102
# Epoch 33/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.0089 - val_loss: 0.0090
# Epoch 34/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0094 - val_loss: 0.0086
# Epoch 35/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0081 - val_loss: 0.0085
# Epoch 36/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0085 - val_loss: 0.0081
# Epoch 37/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0083 - val_loss: 0.0078
# Epoch 38/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0087 - val_loss: 0.0078
# Epoch 39/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.0086 - val_loss: 0.0080
# Epoch 40/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0081 - val_loss: 0.0101
# Epoch 41/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - loss: 0.0087 - val_loss: 0.0077
# Epoch 42/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0084 - val_loss: 0.0083
# Epoch 43/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - loss: 0.0083 - val_loss: 0.0082
# Epoch 44/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - loss: 0.0087 - val_loss: 0.0080
# Epoch 45/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0079 - val_loss: 0.0078
# Epoch 46/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0091 - val_loss: 0.0079
# Epoch 47/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0081 - val_loss: 0.0077
# Epoch 48/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0082 - val_loss: 0.0078
# Epoch 49/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0084 - val_loss: 0.0080
# Epoch 50/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0082 - val_loss: 0.0075
# Epoch 51/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0079 - val_loss: 0.0079
# Epoch 52/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0075 - val_loss: 0.0085
# Epoch 53/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0088 - val_loss: 0.0087
# Epoch 54/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0082 - val_loss: 0.0097
# Epoch 55/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0089 - val_loss: 0.0077
# Epoch 56/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0087 - val_loss: 0.0076
# Epoch 57/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0086 - val_loss: 0.0075
# Epoch 58/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0089 - val_loss: 0.0074
# Epoch 59/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0083 - val_loss: 0.0074
# Epoch 60/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0081 - val_loss: 0.0081
# Epoch 61/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0081 - val_loss: 0.0074
# Epoch 62/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0081 - val_loss: 0.0073
# Epoch 63/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0085 - val_loss: 0.0074
# Epoch 64/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0079 - val_loss: 0.0075
# Epoch 65/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0080 - val_loss: 0.0078
# Epoch 66/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0086 - val_loss: 0.0077
# Epoch 67/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0076 - val_loss: 0.0080
# Epoch 68/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0085 - val_loss: 0.0084
# Epoch 69/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0076 - val_loss: 0.0081
# Epoch 70/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0086 - val_loss: 0.0081
# Epoch 71/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0092 - val_loss: 0.0083
# Epoch 72/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0079 - val_loss: 0.0079
# Epoch 73/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0085 - val_loss: 0.0084
# Epoch 74/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0081 - val_loss: 0.0078
# Epoch 75/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0077 - val_loss: 0.0077
# Epoch 76/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0084 - val_loss: 0.0074
# Epoch 77/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0081 - val_loss: 0.0086
# Epoch 78/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0087 - val_loss: 0.0076
# Epoch 79/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0079 - val_loss: 0.0077
# Epoch 80/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0077 - val_loss: 0.0077
# Epoch 81/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0083 - val_loss: 0.0079
# Epoch 82/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0076 - val_loss: 0.0072
# Epoch 83/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0080 - val_loss: 0.0080
# Epoch 84/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0076 - val_loss: 0.0076
# Epoch 85/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0078 - val_loss: 0.0072
# Epoch 86/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0077 - val_loss: 0.0071
# Epoch 87/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0076 - val_loss: 0.0077
# Epoch 88/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.0082 - val_loss: 0.0072
# Epoch 89/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0071 - val_loss: 0.0073
# Epoch 90/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0083 - val_loss: 0.0077
# Epoch 91/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0079 - val_loss: 0.0073
# Epoch 92/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0080 - val_loss: 0.0072
# Epoch 93/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0071 - val_loss: 0.0074
# Epoch 94/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0079 - val_loss: 0.0075
# Epoch 95/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0078 - val_loss: 0.0071
# Epoch 96/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0076 - val_loss: 0.0073
# Epoch 97/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0074 - val_loss: 0.0078
# Epoch 98/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0079 - val_loss: 0.0074
# Epoch 99/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0079 - val_loss: 0.0072
# Epoch 100/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0071 - val_loss: 0.0071

# %%
trainPredict = model2.predict(trainX)
testPredict = model2.predict(testX)
# Out:
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
trainPredict.shape
# Out:
# (9569, 20)

# %%
trainY.shape
# Out:
# (9569, 20)

# %%
trainPredict = scaler.inverse_transform(trainPredict)
testPredict = scaler.inverse_transform(testPredict)
trainY= scaler.inverse_transform(trainY)
testY= scaler.inverse_transform(testY)

# %%
from sklearn.metrics import  mean_squared_error as mse
import math

# %%
train_RMSE = math.sqrt(mse(trainPredict,trainY))
test_RMSE = math.sqrt(mse(testPredict,testY))

# %%
train_RMSE
# Out:
# 11.098465038395899

# %%
test_RMSE
# Out:
# 11.002766348040401

# %%
trainPredict[:10]
# Out:
# array([[35.90373 , 36.533764, 35.307602, 34.75243 , 36.819107, 37.900173,
#         38.045956, 42.171738, 44.062973, 44.62883 , 45.90972 , 47.331448,
#         49.002056, 50.81505 , 50.52899 , 52.207348, 51.87976 , 50.768543,
#         52.98124 , 54.88389 ],
#        [39.72061 , 39.381   , 38.179775, 38.239067, 39.567535, 41.435555,
#         41.95363 , 46.91233 , 48.444542, 48.717983, 50.480423, 51.27739 ,
#         52.60772 , 54.242622, 53.12785 , 55.004154, 54.802704, 53.98939 ,
#         56.338795, 57.632774],
#        [43.69819 , 43.553326, 43.091244, 44.569687, 45.018047, 47.12807 ,
#         48.413864, 53.068344, 54.204918, 54.733147, 57.031914, 57.658733,
#         58.072273, 59.96683 , 58.94635 , 60.723316, 61.04563 , 61.04691 ,
#         63.15922 , 63.15507 ],
#        [45.887177, 46.39258 , 46.549835, 48.86779 , 48.956207, 50.890274,
#         52.52377 , 56.314934, 57.170902, 57.908325, 60.344795, 60.913857,
#         60.707054, 62.741615, 62.24958 , 63.612904, 64.20893 , 64.80701 ,
#         66.410645, 65.73425 ],
#        [50.01356 , 51.274197, 51.866314, 54.929768, 55.181553, 57.114418,
#         58.802216, 62.255695, 63.11785 , 64.257454, 66.60936 , 67.50772 ,
#         66.78254 , 69.20774 , 69.36078 , 70.63035 , 71.51053 , 72.24768 ,
#         73.60011 , 72.9646  ],
#        [53.121193, 55.12214 , 56.214916, 60.010094, 60.93402 , 63.135796,
#         64.80726 , 68.25221 , 69.470215, 70.95136 , 73.16099 , 74.45203 ,
#         73.4693  , 76.342064, 76.589226, 78.39321 , 79.25801 , 79.933586,
#         81.54226 , 80.97783 ],
#        [54.964355, 57.717216, 59.50828 , 64.19565 , 66.06314 , 68.77362 ,
#         52.988   , 52.567   , 53.828995, 55.543   , 54.524   , 56.077   ,
#         57.71    , 57.84    , 58.099   , 58.713   , 59.328   , 57.646   ,
#         56.496998, 56.19    ],
#        [54.54    , 52.421   , 51.208   , 50.691   , 51.483   , 52.988   ,
#         52.567   , 53.828995, 55.543   , 54.524   , 56.077   , 57.71    ,
#         57.84    , 58.099   , 58.713   , 59.328   , 57.646   , 56.496998,
#         56.19    , 31.67    ]], dtype=float32)

# %%
plt.plot(testY[800:1200,19], color='r')
plt.plot(testPredict[800:1200,19])

# %%
x_test = np.array([0.067932,0.23938,3.3028,5.7289,13.299,19.154,23.278,29.618,32.772,34.746])
x_test = x_test.reshape((-1, 10,1))
print(x_test.shape)
# Out:
# (1, 10, 1)

# %%
yhat = model2.predict(x_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step

# %%
yhat
# Out:
# array([[11.086247, 15.443157, 27.148813, 17.693972, 24.02262 , 24.613335,
#         35.02728 , 25.492077, 27.829796, 29.87483 , 37.277237, 39.06393 ,
#         45.400913, 39.618484, 40.779037, 48.182087, 39.45638 , 46.4967  ,
#         45.58452 , 39.25497 ]], dtype=float32)

# %% [markdown]
# ## Testing the model

# %%
TestData = pd.read_csv("test_10-20.csv",index_col = 0)
TestData = TestData.values
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 TestData = pd.read_csv("test_10-20.csv",index_col = 0)
#       2 TestData = TestData.values
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File ~\anaconda3\Lib\site-packages\pandas\io\common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test_10-20.csv'

# %%
n_steps_in, n_steps_out = 10,20
n_features = 1

# %%
x_test = TestData[:,0:n_steps_in]
y_test = TestData[:,n_steps_in : n_steps_in+n_steps_out]

# %%
# x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], n_features))
# print(x_train.shape)
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], n_features))
print(x_test.shape)
# y_train = y_train.reshape((y_train.shape[0], y_train.shape[1], n_features))
# print(y_train.shape)
y_test = y_test.reshape((y_test.shape[0], y_test.shape[1]))
print(y_test.shape)

# %%
y_predicttest = model2.predict(x_test)

# %%
math.sqrt(mse(y_predicttest,y_test))

# %%
def rmse(pred, actual):
    error = np.subtract(pred, actual)
    sqerror= np.sum(np.square(error))/actual.shape[0]
    return np.sqrt(sqerror)

# %%
# train_acc=np.zeros(Num_Exp)
test_acc=np.zeros(1)
Step_RMSE=np.zeros([1,n_steps_out])

# %%
test_acc[0] = rmse( y_predicttest, y_test)

# %%
# train_acc[0] = rmse( y_predicttrain,y_train)
test_acc[0] = rmse( y_predicttest, y_test)

# %%
Best_RMSE=test_acc[0]
Best_Predict_Test=y_predicttest

# %%
for j in range(n_steps_out):
    Step_RMSE[0][j]=rmse(y_predicttest[:,j], y_test[:,j])

# %%
Best_Predict_Test.reshape(y_test.shape[0], y_test.shape[1])

# %%
x_data=np.linspace(0,y_test.shape[0], num=y_test.shape[0])
for j in range(n_steps_out):
    plt.figure()
    plt.plot(x_data, y_test[:,j], label='actual')
    plt.plot(x_data, Best_Predict_Test[:,j], label='predicted')
    plt.ylabel('RMSE')
    plt.xlabel('Time (samples)')
    plt.title('Actual vs Predicted')
    plt.legend()
    plt.show()
    plt.close()

# %%
a= Best_Predict_Test.reshape(y_test.shape[0], y_test.shape[1])
a.shape

# %%
list1=[]
for i in range(len(a[0])):
    list1.append(a[0][i])

# %%
list1

# %%
b= TestData[:,5:15]

# %%
list2=[]
for i in range(len(b[0])):
    list2.append(b[0][i])

# %%
list2

# %%
from keras.models import load_model

model2.save('Attention model LSTM.keras')
